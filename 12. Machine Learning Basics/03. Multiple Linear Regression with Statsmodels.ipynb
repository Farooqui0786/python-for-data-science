# %%
# import pandas for data handling
import pandas as pd

# %%
# read the csv file into dataframe & show the dataset
df_boston = pd.read_csv('Boston House Prices.csv')
df_boston
# Out:
#      Rooms  Distance  Value
# 0    6.575    4.0900   24.0
# 1    6.421    4.9671   21.6
# 2    7.185    4.9671   34.7
# 3    6.998    6.0622   33.4
# 4    7.147    6.0622   36.2
# ..     ...       ...    ...
# 501  6.593    2.4786   22.4
# 502  6.120    2.2875   20.6
# 503  6.976    2.1675   23.9
# 504  6.794    2.3889   22.0
# 505  6.030    2.5050   11.9
#
# [506 rows x 3 columns]

# %% [markdown]
# ## **Multiple Linear Regression with Statsmodels**

# %%
# import statsmodels library for statistical modeling
import statsmodels.api as sm

# %%
# define dependent and independent variable
y = df_boston['Value']      # dependent
x = df_boston[['Rooms', 'Distance']]      # independent

# %% [markdown]
# ### **Making the Regression: Adding a constant and fitting the model**

# %% [markdown]
# **Statsmodels doesn't add a constant by default, so we have to do it on our own**

# %%
x = sm.add_constant(x)      # adding constant
lm = sm.OLS(y,x).fit()      # fitting the model

# %%
# use the trained model 'lm' to make predictions on input data x
lm.predict(x)
# Out:
# 0      25.232623
# 1      24.305975
# 2      31.030253
# 3      29.919727
# 4      31.231138
#          ...
# 501    24.603318
# 502    20.346831
# 503    27.822178
# 504    26.328552
# 505    19.661029
# Length: 506, dtype: float64

# %%
# the regression table
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Value   R-squared:                       0.496
# Model:                            OLS   Adj. R-squared:                  0.494
# Method:                 Least Squares   F-statistic:                     247.0
# Date:                Sat, 06 Sep 2025   Prob (F-statistic):           1.84e-75
# Time:                        10:16:28   Log-Likelihood:                -1667.1
# No. Observations:                 506   AIC:                             3340.
# Df Residuals:                     503   BIC:                             3353.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6361      2.621    -13.212      0.000     -39.786     -29.486
# ...
