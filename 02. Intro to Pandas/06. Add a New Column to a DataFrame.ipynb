# %%
# Import pandas library for data handling and analysis
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
# showing the dataframe
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## **Adding a New Column**

# %% [markdown]
# **Adding a New Column with a Scalar Value**

# %%
# adding new column to a dataframe
df_exams['language score'] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# 2                70
# 3                70
# 4                70
# ..              ...
# 995              70
# 996              70
# 997              70
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %% [markdown]
# **Adding a New Column with an Array** -> The dataframe has 1000 rows, so we need to create an array with 1000 elements

# %%
# import numpy
import numpy as np

# %%
# create an array of 1000 elements
language_score = np.arange(0, 1000)

# %%
# length of the array
len(language_score)
# Out:
# 1000

# %%
# adding a new column to a dataframe with an array
df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
# create random integer numbers between 1 and 100
int_language_score = np.random.randint(1, 100, size=1000)

# %%
# min value inclusive & high value exclusive
print(min(int_language_score))
print(max(int_language_score))
# Out:
# 1
# 99

# %%
# adding a new column to a dataframe with an array
df_exams['language score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                39
# 1                12
# 2                 8
# 3                 9
# 4                15
# ..              ...
# 995              28
# 996              56
# 997              86
# 998              13
# 999              53
#
# [1000 rows x 9 columns]

# %%
# create random float numbers between 1 and 100
np.random.uniform(1, 100, size=1000)
# Out:
# array([21.27907253, 60.7422395 , 51.88122312, 55.68050388, 74.38719583,
#        49.61713608, 53.20048995, 88.21415448, 32.12450894, 63.25243483,
#        39.08156639, 27.35736034, 85.21666797, 62.35404201, 10.47190035,
#        22.03428147, 24.35132611, 40.5589012 , 72.90642909,  9.07065183,
#         2.85596699, 80.13822182, 53.20696193, 23.71135354,  9.94743844,
#        50.48375039, 97.71187913, 73.26256461, 38.80682352, 22.81174192,
#        90.51769196, 59.03573417, 48.91257945, 17.56036951, 75.16493963,
#         1.62661532, 35.57951275, 67.43717781, 86.04280973, 73.0835064 ,
#         1.43445559, 20.74146615, 74.03542567, 97.10631985,  9.27298473,
#        38.43760458, 47.67982544, 46.6963624 , 80.60815604, 54.45593385,
#        86.59899162, 14.11834696, 87.7390839 , 86.46402899, 88.08828079,
#        16.41367229, 77.46875192, 31.3794997 , 56.64729591, 49.65581313,
#         8.73441203, 87.03365571, 38.77446276, 58.23201011, 93.9772823 ,
#        75.08475616,  8.31824791, 46.77605261, 77.73962149, 62.36009742,
#        75.29604715, 45.61372964, 24.72767908, 55.29190852,  3.37358256,
#        64.40837158, 78.69511665, 55.48819428, 61.7414477 , 56.87555185,
#        54.24085127, 41.70538975, 67.40349081,  8.32587519, 68.52492552,
#        50.76163394, 22.02370743, 62.17096566, 78.97189868, 29.07164753,
#        88.4329018 , 66.59589654, 41.13801795, 36.77111749, 86.22894919,
#        97.95219504, 65.22519024,  5.92874312, 94.9530948 , 96.38116092,
#        60.26691502, 95.09778504, 41.05698824, 69.30419958, 72.39303351,
#        72.43705916, 66.94145331, 41.86753824, 84.96565174, 10.07180202,
#        25.79656738, 59.50065413, 43.23931164, 45.96007059, 56.6955413 ,
#        75.89740901, 65.95657573, 62.05541093,  9.58659392, 37.4661008 ,
#        48.07600357,  6.67257092, 11.0413282 ,  1.56963004, 92.35488211,
#        74.26840551, 76.85450858, 86.33316247, 49.53264406, 61.35695073,
#        29.00088496, 32.16419841, 49.99204632, 47.59089962, 61.24202263,
#        98.45672577, 95.78009308, 61.96040074, 97.61440466,  3.73026835,
#         6.34130032, 96.76722891, 77.91035509, 24.40338171, 73.00294887,
#         8.04498794,  8.24775729, 74.01459198, 64.21483753, 89.74343417,
#        34.46012279, 26.65808118,  4.72643958, 72.68627701, 49.31831884,
#        46.07200948, 93.12238839, 81.6556932 , 13.69880096, 18.5716277 ,
#        85.53250536, 86.9020611 ,  3.62708326, 26.53440712, 85.01570131,
#        32.92311717, 68.28431123,  8.70766573, 40.26929693, 49.85190714,
#        11.70270351, 67.01244897, 34.07156171, 90.5059356 ,  4.50441582,
#        57.15440343, 58.19655982, 52.37886472, 30.31370172, 59.97639385,
#        27.03675209, 43.35514524, 95.58075658, 96.53978497, 47.34616424,
#        39.09687903, 51.8550542 , 99.44339004,  5.66156309, 65.08621524,
#        56.74564621, 30.29881303,  8.7126625 ,  9.5362188 , 89.52336433,
#        60.5829322 , 73.20515248, 94.31329879, 77.73459901,  9.5556215 ,
#        41.58103549,  8.78159997, 20.53114434, 52.60832864, 42.39123266,
#        71.43150607, 96.69753755, 54.92542848, 47.60430759, 48.67935476,
#        31.33073601, 85.90674747, 48.17785956, 52.72329107, 42.51443373])

# %% [markdown]
# **assign()** ->
# When to use assign?
# * Add multiple columns in a single line of code
# * When you need to overwrite the values of an existing columns (best practice)
# * It returns a new object (a copy) with all the original columns in addition to the new ones

# %%
# create random numbers for our new score columns
score1 = np.random.randint(1, 100, size=1000)
score2 = np.random.randint(1, 100, size=1000)

# %%
# create a series using the random numbers
series1 = pd.Series(score1, index=np.arange(0, 1000))
series2 = pd.Series(score2, index=np.arange(0, 1000))

# %%
# using assign() to add multiple columns
df_exams = df_exams.assign(score1=series1, score2=series2)

# %%
# showing the dataframe
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                39      57      42
# 1                12      39      69
# 2                 8      21      66
# 3                 9       7      47
# 4                15      17      92
# ..              ...     ...     ...
# 995              28      72      29
# 996              56      60      57
# 997              86       4      84
# 998              13       3      91
# 999              53      98      40
#
# [1000 rows x 11 columns]

# %% [markdown]
# **insert()** -> Inserts a new column at a specific position or index.

# %%
# using insert() to add a column at a specific position
df_exams.insert(1, 'test', series1)

# %%
# showing the dataframe
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    57        group B           bachelor's degree      standard
# 1    female    39        group C                some college      standard
# 2    female    21        group B             master's degree      standard
# 3      male     7        group A          associate's degree  free/reduced
# 4      male    17        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    72        group E             master's degree      standard
# 996    male    60        group C                 high school  free/reduced
# 997  female     4        group C                 high school  free/reduced
# 998  female     3        group D                some college      standard
# 999  female    98        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                39      57      42
# 1                12      39      69
# 2                 8      21      66
# 3                 9       7      47
# 4                15      17      92
# ..              ...     ...     ...
# 995              28      72      29
# 996              56      60      57
# 997              86       4      84
# 998              13       3      91
# 999              53      98      40
#
# [1000 rows x 12 columns]
